# %%
from numpy import zeros, newaxis
import numpy as np
import cv2
import dlib
from imutils import face_utils
import matplotlib.pyplot as plt
import copy

def Landmark_Perspective(root):
    # Face landmark Prediction
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

    # Default Variable Setting
    image = cv2.imread(root)
    rects = detector(image, 1)
    global blank_image
    for (i, rect) in enumerate(rects):
        shape = predictor(image, rect)
        shape = face_utils.shape_to_np(shape)

        pts1 = 19
        pts2 = 24
        pts3 = 6
        pts4 = 10

        src = np.float32([shape[pts1],shape[pts2], shape[pts3], shape[pts4]])
        width, height = 250, 250
        w_margin, h_margin = 2*width * 0.1, 2*height * 0.1

        dts = np.float32([[w_margin, 0], [width-w_margin,0 ],
                           [w_margin,height - 0.5*h_margin], [width - w_margin, height - 0.5*h_margin]])

        mtrx = cv2.getPerspectiveTransform(src, dts)
        result = cv2.warpPerspective(image, mtrx, (width, height))

        z = np.ones((68, 1))
        shape_3d = np.concatenate((shape, z), axis=1)
        matmul_shape = np.matmul(shape_3d, mtrx.T)  # Transposed matrix for correct multiplication

        # Adjusting for valid coordinates and transforming shape
        col1 = matmul_shape[:, 0] / (matmul_shape[:, 2])
        col2 = matmul_shape[:, 1] / (matmul_shape[:, 2])
        col1 = np.reshape(col1, (68, 1))
        col2 = np.reshape(col2, (68, 1))
        transform_shape = np.concatenate((col1, col2), axis=1)

        # Adjust coordinates function to avoid negative values
        def adjust_coordinates(coord):
            x, y = coord
            return (max(int(x), 0), max(int(y), 0))
        
        blank_image = np.zeros(result.shape, dtype=np.uint8)
        # Drawing circles on transformed landmarks
        for point in transform_shape:
            cv2.circle(blank_image, adjust_coordinates(point), 1, (255, 255, 255), -1)
    return blank_image

# %%
import os

folder_dir = "C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_org/"
folder_list = os.listdir(folder_dir)

# 폴더 내 파일 리스트 가져오기
files_list =  os.listdir(f'C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_org/{folder_list[4]}')

# 폴더 내 각 파일에 대해 Landmark_Perspective 함수 적용
for file_name in files_list:
    files_dir = f'C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_org/{file_name[:1]}/'
    file_path = os.path.join(files_dir, file_name)
    result = Landmark_Perspective(file_path)
    if result is None :
        continue
    if result.size > 0 :
        image_path = f"C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/{file_name[:1]}/{file_name}"
        print(image_path)
        cv2.imwrite(image_path, result)
    # 결과 사용 또는 저장 등 추가 작업 수행
# Out:
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_0.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1002.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1005.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1008.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1011.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1014.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1017.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1020.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1023.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1029.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1032.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1035.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1038.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1041.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1044.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1047.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1050.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1053.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1056.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1059.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1065.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1068.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1071.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1074.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1077.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1080.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1083.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1086.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1089.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1092.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1095.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1098.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1101.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1104.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1107.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1110.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1113.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1116.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1119.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1122.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1125.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1128.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1131.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1134.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1137.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1140.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1143.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1146.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1152.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1161.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1164.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1167.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1170.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1173.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1176.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1179.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1182.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1185.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1191.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_12.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1209.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1212.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1215.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1218.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1221.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1224.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1227.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1230.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1233.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1236.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1239.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1242.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1245.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1248.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1254.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1257.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1263.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1266.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1269.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1272.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1275.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1278.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1281.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1284.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1287.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1290.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1299.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1302.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1305.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_1308.jpg
# C:/Users/PC/Desktop/tnfla/Face Recognition Deep Learning/face_data_ldmk/4/4_
        random.shuffle(self.files_list)
        self.transform = transform
        self.ratio_train = ratio_train
        self.ds_type = ds_type
        
        self.num_train = int(self.ratio_train * len(self.files_list))
        self.num_test = len(self.files_list) - self.num_train
        
        if self.ds_type == 'train':
            self.files_list = self.files_list[:self.num_train]
        elif self.ds_type == 'test':
            self.files_list = self.files_list[self.num_train:]

    def __getitem__(self, index):
        image_name = self.files_list[index]
        self.files_dir = f'./face_data_ldmk/{image_name[:1]}/'

        image_path = os.path.join(self.files_dir, self.files_list[index])
        
        input = Image.open(image_path)
        input = self.transform(input)
        target = int(image_name[:1])
        return input,target

    def __len__(self):
        if self.ds_type == 'train':
            return self.num_train
        
        elif self.ds_type == 'test':
            return self.num_test

# %%
folder_dir = f'./face_data_ldmk/'
input_size = 250*250
batch_size = 32
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
])

# %%
ds_train = Face_Dataset(folder_dir=folder_dir,transform=transform,ratio_train=0.7,ds_type='train')
ds_test =Face_Dataset(folder_dir=folder_dir,transform=transform,ratio_train=0.7,ds_type='test')

dl_train = torch.utils.data.DataLoader(dataset = ds_train,batch_size=batch_size,shuffle = True,drop_last=True)
dl_test = torch.utils.data.DataLoader(dataset = ds_test,batch_size=batch_size,shuffle = True,drop_last=True)

# %%
train_features, train_labels = next(iter(dl_train))
train_features.size()
# Out:
# torch.Size([32, 1, 128, 128])

# %%
import matplotlib.pyplot as plt
import numpy as np

name = ['0', '1', '2', '3', '4']

fig, axs = plt.subplots(1, 10, figsize=(20, 2))
for i in range(10):
    img = ds_train[i][0].numpy()  # 텐서를 넘파이 배열로 변환
    label = ds_train[i][1]
    
    img = np.transpose(img, (1, 2, 0))  # 축 변경 (채널, 높이, 너비) -> (높이, 너비, 채널)
    img = (img - img.min()) / (img.max() - img.min())  # 정규화
    
    axs[i].imshow(img)  
    axs[i].set_title(name[label])
    axs[i].axis('off')
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class BalancedCNN(torch.nn.Module):
    def __init__(self):
        super(BalancedCNN, self).__init__()
        # 드롭아웃 확률을 적절히 높여 규제 강화 (기존 0.5에서 0.4로 낮춤)
        self.keep_prob = 0.2

        self.layers = torch.nn.Sequential(
            # Convolutional Layer 1: 채널 수 32 -> 24로 감소
            torch.nn.Conv2d(1, 64, kernel_size=2, padding=3),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2),
            
            # Convolutional Layer 2: 채널 수 128 -> 96으로 감소
            torch.nn.Conv2d(64, 128, kernel_size=3),
            torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2),
            
            # Flatten layer
            torch.nn.Flatten(),
            
            # Fully Connected Layer 1: 뉴런 수 감소
            # 입력 이미지 128x128 가정 시 최종 특성 맵 크기: 96 * 32 * 32 = 98304
            torch.nn.Linear(128*32*32, 64, bias=True),
            torch.nn.BatchNorm1d(64),
            torch.nn.ReLU(),
            # 드롭아웃 확률 p=0.6으로 설정
            torch.nn.Dropout(p=1 - self.keep_prob),
            
            # Fully Connected Layer 2
            torch.nn.Linear(64, 5, bias=True),
            torch.nn.Softmax(dim=1)
        )
        self._initialize_weights()

    def forward(self, x):
        out = self.layers(x)
        return out
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

# GPU 사용 가능 여부 확인 후 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"사용 중인 디바이스: {device}")

# 수정된 모델을 GPU로 옮기기
model = BalancedCNN().to(device)
# Out:
# 사용 중인 디바이스: cuda

# %%
import torch
import time

# 모델 학습에 필요한 하이퍼파라미터 설정
learning_rate = 0.001
num_epochs = 30

start = time.time()
# 옵티마이저, 손실 함수 및 장치 설정
opt = optim.SGD(model.parameters(), lr=3e-3, momentum=0.9)
loss_criterion = torch.nn.CrossEntropyLoss()
device = torch.device("cuda")

# 모델 평가 함수 정의

# 학습 및 평가 루프
losses = []
acces = []

for epoch in range(num_epochs):
    model.train()  # 학습 모드로 설정
    loss_avg = 0
    corrects = 0
    
    torch.cuda.empty_cache()
    for imgs, targets in dl_train:
        imgs, targets = imgs.to(device), targets.to(device)
        # print(targets.shape)
        imgs = imgs.to(torch.float)
        # imgs = imgs[:, 0, :,:].unsqueeze(0)
        output = model(imgs)
        # preds = F.softmax(output,dim=1)
        # print(preds.shape)
        preds = torch.argmax(output, dim=1)
        # preds = (output >= 0.5).float()
        loss = loss_criterion(output, targets)
        
        opt.zero_grad()
        loss.backward()
        opt.step()
        
        loss_avg += loss.item()
        corrects += (targets == preds).sum().item()
        # ⭐ 중요한 부분: 연산 후 텐서들을 명시적으로 삭제
        del imgs, targets, output, preds, loss
        
        # ⭐ GPU 캐시 메모리 정리
        torch.cuda.empty_cache()
        
    loss_avg = loss_avg / len(dl_train)
    losses.append(loss_avg)
    acc = corrects / len(dl_train.dataset)
    acces.append(acc)

    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch + 1}; Test Accuracy: {acc:.4%}')
        # print(out)


    print(f"Epoch {epoch + 1}; Loss: {loss_avg:.4f}")
print("time:",time.time() - start)
# Out:
# Epoch 1; Loss: 1.3562
# Epoch 2; Loss: 1.2379
# Epoch 3; Loss: 1.1804
# Epoch 4; Loss: 1.1443
# Epoch 5; Loss: 1.1280
# Epoch 6; Loss: 1.0963
# Epoch 7; Loss: 1.0933
# Epoch 8; Loss: 1.0823
# Epoch 9; Loss: 1.0630
# Epoch 10; Test Accuracy: 87.9143%
# Epoch 10; Loss: 1.0551
# Epoch 11; Loss: 1.0469
# Epoch 12; Loss: 1.0460
# Epoch 13; Loss: 1.0361
# Epoch 14; Loss: 1.0338
# Epoch 15; Loss: 1.0303
# Epoch 16; Loss: 1.0312
# Epoch 17; Loss: 1.0231
# Epoch 18; Loss: 1.0166
# Epoch 19; Loss: 1.0158
# Epoch 20; Test Accuracy: 90.7714%
# Epoch 20; Loss: 1.0136
# Epoch 21; Loss: 1.0014
# Epoch 22; Loss: 1.0082
# Epoch 23; Loss: 1.0052
# Epoch 24; Loss: 0.9971
# Epoch 25; Loss: 0.9979
# Epoch 26; Loss: 1.0002
# Epoch 27; Loss: 0.9930
# Epoch 28; Loss: 0.9946
# Epoch 29; Loss: 0.9953
# Epoch 30; Test Accuracy: 92.2286%
# Epoch 30; Loss: 0.9937
# time: 294.22519516944885

# %%
model.eval()  # 평가 모드로 설정
corrects = 0
errors = 0
threshold = 0.4

with torch.no_grad():  # 그라디언트 계산 비활성화 -> 메모리 사용량을 줄이고 연산 속도를 높이기 위함 (gradient 사용 안할 때 효율을 높이기 위해 사용)
    for imgs, targets in dl_test:
        imgs, targets = imgs.to(device), targets.to(device)  # CPU로 텐서를 이동시킴
        imgs = imgs.to(torch.float)  # 이미지를 float 형식으로 변환
        out = model(imgs)   # 모델로 예측

        probabilities = torch.softmax(out, dim=1)
        preds = (probabilities >= threshold).int().argmax(dim=1)
        corrects += (targets == preds).sum().item()  # 정확하게 예측된 수 계산
        errors += len(targets) - (targets == preds).sum().item() # 잘못 예측된 수 계산


acc = corrects / len(dl_test.dataset) # 정확도 계산
print(f'Final Test Accuracy: {acc:.4%},  Final Errors: {errors}')
# Out:
# Final Test Accuracy: 91.2000%,  Final Errors: 104

# %%
import torch
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score

# 모델 평가 함수 (이전 답변에서 제공된 수정된 코드)
def get_clf_eval(y_test, pred):
    y_test_np = y_test.cpu().numpy()
    pred_np = pred.cpu().numpy()
    
    confusion = confusion_matrix(y_test_np, pred_np)
    accuracy = accuracy_score(y_test_np, pred_np)
    precision = precision_score(y_test_np, pred_np, average='micro')
    
    return accuracy, precision, confusion

# --- 모델 평가 루프 ---

model.eval() # 모델을 평가 모드로 전환
all_preds = []
all_targets = []

# DataLoader를 사용하여 테스트 데이터셋을 순회
with torch.no_grad(): # 기울기 계산 비활성화 (메모리 절약)
    for imgs, targets in dl_test:
        imgs, targets = imgs.to(device), targets.to(device)  # CPU로 텐서를 이동시킴
        imgs = imgs.to(torch.float)  # 이미지를 float 형식으로 변환
        out = model(imgs)   # 모델로 예측

        probabilities = torch.softmax(out, dim=1)
        preds = (probabilities >= threshold).int().argmax(dim=1)
        
        # 배치별 예측값과 실제값을 리스트에 추가
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(targets.cpu().numpy())

# 전체 데이터에 대한 평가
total_confusion = confusion_matrix(all_targets, all_preds)
total_accuracy = accuracy_score(all_targets, all_preds)
total_precision = precision_score(all_targets, all_preds, average='micro')

print(f"전체 데이터셋 Accuracy: {total_accuracy:.4f}")
print(f"전체 데이터셋 Precision: {total_precision:.4f}")
print("전체 데이터셋 Confusion Matrix:")
print(total_confusion)
# Out:
# 전체 데이터셋 Accuracy: 0.9287
# 전체 데이터셋 Precision: 0.9287
# 전체 데이터셋 Confusion Matrix:
# [[275   0   0   0   0]
#  [ 18 267   0   2   1]
#  [ 13   0 291   0   0]
#  [ 26   0   1 273   0]
#  [ 41   1   2   0 261]]

# %%
plt.plot(losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"Loss Over Epochs (Average Loss: {loss_avg:.4f})")
plt.show()

# %%
plt.plot(acces)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title(f"Accuracy Over Epochs (Final_acc: {acc:.4f})")
plt.show()

# %%
import torch

# 모델 전체를 저장하는 코드
torch.save(model, 'L.ver_model.pth')

# 저장된 모델을 불러오는 코드
model = torch.load('L.ver_model.pth')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2524\3694259342.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('L.ver_model.pth')
